# %%
class Registration():

    def first_name():
        while True:
            first_name = input("enter your first name here : ")

            try:
                if first_name.isalpha() and len(first_name) >= 2:
                    print(f"Your first name : {first_name}")
                    break

                if any(char.isdigit() for char in first_name):
                    raise ValueError ("Only alphabets are allowed")
                # else:
                #     print("Please enter the right name which contains alphabets only")
                #     continue
            except ValueError as ve :
                print(f"Invalid name : {ve}")


    
    def last_name():

        while True:
            last_name = input("enter your last name here : ")

            try:
                
                if last_name.isalpha() and len(last_name) >= 2:
                    print(f"Your last name : {last_name}")
                    break
                if (char.isdigit() for char in last_name):
                    raise ValueError ("Only alphabets are allowed")
                
            except ValueError as ve:
                print(f"Invalid Name : {ve}")

    def mobile_no():
        while True:

            mb_no = input("enter your mobile number")

            try:

                if mb_no.isdigit() and len(mb_no) == 10:
                    print(f"Your mobile number : {mb_no}")
                    break

                if any(char.isalpha()for char in mb_no):
                    raise ValueError ("Only numbers are allowed and length should be 10")
                
            except ValueError as ve:
                print(f"Invalid number : {ve}")



    
    
    def email():
        
        while True:

            import re
            email_id = input("enter your email address : ")
            pattern = "^[a-z0-9.]+[\._]?[a-z0-9]+[@]\w+[.]\w{2,3}$"
            validate_email = lambda email_id : re.search(pattern, email_id)

            try:
                import re
                if re.search(pattern, email_id):
                    print("Valid email id")
                    print(f"your email id : {email_id}")
                    break

                else:
                    print("Invalid email id")

            except Exception as e:
                print(f"error : {e}")


    # from datetime import datetime
    # import datetime

    # def dob():

    #     try:
    #         current_date = datetime.now()
    #         date=datetime.strptime(value, '%Y-%m-%d')
    #         if date >= current_date:
    #                 error = 'Date of birth cannot be in the future.'
    #         else:
    #             dobdate = date.strftime('%Y-%b-%d')
    #             return dobdate
    #     except:
    #             error = 'Wrong date format! '


    from datetime import datetime

    
    def dob():

        dob = input("Enter your date of birth (YYYY-MM-DD): ")
        calculate_age = lambda dob : (datetime.today().year - dob.year) - ((datetime.today().month, datetime.today().day) < (dob.month, dob.day))

        try:
            from datetime import datetime
            dob_format = '%Y-%m-%d'
            dob_datetime = datetime.strptime(dob, dob_format)

            # Calculate the age using the lambda function
            age = calculate_age(dob_datetime)
            print("Your birth : {dob}")
            print(f"Your age : {age}")

            if age >= 18:
                return "Valid date of birth"
            else:
                return "Invalid date of birth: Age must be at least 18 years old"
        except ValueError:
            return "Invalid date of birth: Incorrect format"
    


    f_obj = first_name()
    l_obj = last_name()
    m_obj = mobile_no()
    email_obj = email()
    dob_obj = dob()
# Out:
# Your first name : vikrant
# Your last name : shinde
# Your mobile number : 1234567890
# Valid email id
# your email id : abc_123@gmail.com
# Your birth : {dob}
# Your age : -1
