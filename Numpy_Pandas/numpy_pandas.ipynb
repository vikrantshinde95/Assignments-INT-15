# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
df = pd.read_excel("D:\\My_assignments\\Assignments-INT-15\\Numpy_Pandas\\Superstore.xls")
df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Program Files\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 1. Read superstore data

# %%
df = pd.read_excel("Superstore.xls")
df.head()
# Out:
#     no       order _id Order Date  Ship Date       Ship Mode Customer ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### 2.find the index of the data

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %% [markdown]
# ### 3. find the columns of the data

# %%
df.columns
# Out:
# Index(['no', 'order _id', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 4. if columns name is having space then remove the space and rename the column. find the various ways to rename the column

# %%
df.columns = df.columns.str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df = df.rename(columns={"Postal_Code": "pin_code"})
df.columns
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'pin_code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 5.display first 40 records

# %%
df.head(40)
# Out:
#       no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0    NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1    2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2    3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3    4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4    5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5    6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6    7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7    8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8    9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9   10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 10  11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...

# %% [markdown]
# ### 6.display last 15 records from the data

# %%
df.tail(15)
# Out:
#           no       order__id Order_Date  Ship_Date       Ship_Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %% [markdown]
# ### 7.change the setting to display minimum 30 rows for given data

# %%
pd.set_option("display.min_rows",30)

# %% [markdown]
# ### 8.change the display setting to minimum row as 3

# %%
pd.set_option("display.min_rows",3)

# %% [markdown]
# ### 9.take a slice from the dataframe based on the columns city, state, region, profit columns

# %%
df.head()
# Out:
#     no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    pin_code Region       Product_ID         Category Sub-Category  \
# ...

# %%
df.loc[2:6,["City","State","Region","Profit"]]
# Out:
#               City       State Region    Profit
# 2      Los Angeles  California   West    6.8714
# 3  Fort Lauderdale     Florida  South -383.0310
# 4  Fort Lauderdale     Florida  South    2.5164
# 5      Los Angeles  California   West   14.1694
# 6      Los Angeles  California   West    1.9656

# %% [markdown]
# ### 10.Take a slice based on data available at 1000 to 1500 position and columns from 4 to 8

# %%
df.iloc[1000:1501,4:8].head()
# Out:
#            Ship_Mode Customer_ID Customer_Name      Segment
# 1000  Standard Class    FM-14290  Frank Merwin  Home Office
# 1001        Same Day    RH-19495   Rick Hansen     Consumer
# 1002        Same Day    RH-19495   Rick Hansen     Consumer
# 1003        Same Day    RH-19495   Rick Hansen     Consumer
# 1004  Standard Class    RA-19945     Ryan Akin     Consumer

# %% [markdown]
# ### 11.Rename the index starts from 1900 to end of the data

# %%
# df2 = df.iloc[1900:,:]
# df2.head()

# %%
# df3 =df.rename(1900 , 1900 + len(df))

# %%
df.index = range(1900 , 1900+len(df))
df.head()
# Out:
#        no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 1900  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1901  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1902  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 1903  4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 1904  5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#         Customer_Name    Segment        Country             City       State  \
# 1900      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1901      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1902  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 1903   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 1904   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# ### 12.Take a slice from data based on index having name as 1920 , 1940, 1945, 1980, and columns as profit, state, category, sub-category, region

# %%
df.loc[[1920,1940,1945,1980],["Profit","State","Category","Sub-Category","Region"]]
# Out:
#        Profit       State         Category Sub-Category   Region
# 1920   7.3840  California  Office Supplies      Binders     West
# 1940  41.7564       Texas       Technology       Phones  Central
# 1945   8.2062   Minnesota  Office Supplies      Binders  Central
# 1980   8.0352     Alabama  Office Supplies      Binders    South

# %% [markdown]
# ### 13.Check the data type of columns

# %%
df.columns
# Out:
# Index(['no', 'order__id', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'pin_code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 1900 to 11893
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   no             9993 non-null   float64
#  1   order__id      9993 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   Ship_Date      9994 non-null   datetime64[ns]
#  4   Ship_Mode      9994 non-null   object
#  5   Customer_ID    9994 non-null   object
#  6   Customer_Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  pin_code       9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product_ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product_Name   9994 non-null   object
# ...

# %% [markdown]
# ### 14.Find out the record for the month of jun-2014

# %%
df_new.dtypes
# Out:
# no                      float64
# order__id                object
# Order_Date       datetime64[ns]
# Ship_Date        datetime64[ns]
# Ship_Mode                object
# Customer_ID              object
# Customer_Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# pin_code                  int64
# Region                   object
# Product_ID               object
# Category                 object
# Sub-Category             object
# Product_Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
df_new = range((df["Order_Date"]=="2014-06-01" , df["Order_Date"]=="2014-06-30"))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 df_new = range((df["Order_Date"]=="2014-06-01" , df["Order_Date"]=="2014-06-30"))
#
# TypeError: 'tuple' object cannot be interpreted as an integer

# %%
df_new = df[df["Order_Date"] > "2014-06-01"] & [df["Order_Date"] < "2014-06-30"]]
df_new
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df_new = df[[df["Order_Date"] > "2014-06-01"] & [df["Order_Date"] > "2014-06-30"]]
#       2 df_new
#
# TypeError: unsupported operand type(s) for &: 'list' and 'list'

# %% [markdown]
# ### Method-1

# %%
jun_df=df[(df["Order_Date"] >= "2014-06-01") & (df["Order_Date"] <= "2014-06-30")]
jun_df.shape
# Out:
# (135, 21)

# %% [markdown]
# ### Method-2

# %%
new_df = df[(df["Order_Date"].dt.year == 2014) & (df["Order_Date"].dt.month == 6)]
new_df.shape
# Out:
# (135, 21)

# %% [markdown]
# ### 15.Calculate month wise average of profit.

# %%
avg_profit = df.groupby([df["Order_Date"].dt.month])["Profit"].mean()
avg_profit
# Out:
# Order_Date
# 1     23.974924
# 2     34.315369
# 3     41.084321
# 4     17.346462
# 5     30.491575
# 6     29.687302
# 7     19.482626
# 8     30.845522
# 9     26.650380
# 10    38.808353
# 11    24.111779
# 12    30.801983
# Name: Profit, dtype: float64

# %% [markdown]
# ### 16.Create the new data frame for California

# %%
cal_df = df[df["State"] == "California"]
cal_df,cal_df.shape
# Out:
# (           no       order__id Order_Date  Ship_Date       Ship_Mode  \
#  1902      3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
#  1905      6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1906      7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1907      8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1908      9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1909     10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1910     11.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1911     12.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
#  1918     19.0  CA-2014-143336 2014-08-27 2014-09-01    Second Class
#  1919     20.0  CA-2014-143336 2014-08-27 2014-09-01    Second Class
#  1920     21.0  CA-2014-143336 2014-08-27 2014-09-01    Second Class
#  1925     26.0  CA-2016-121755 2016-01-16 2016-01-20    Second Class
#  1926     27.0  CA-2016-121755 2016-01-16 2016-01-20    Second Class
# ...

# %% [markdown]
# ### 17.Find sum of sales

# %%
sum1 = df["Sales"].sum()
sum1
# Out:
# np.float64(2297200.8603000003)

# %%
df.groupby("Product_Name")["Sales"].sum()
# Out:
# Product_Name
# "While you Were Out" Message Book, One Form per Page                                                                                  25.2280
# #10 Gummed Flap White Envelopes, 100/Box                                                                                              41.3000
# #10 Self-Seal White Envelopes                                                                                                        108.6820
# #10 White Business Envelopes,4 1/8 x 9 1/2                                                                                           488.9040
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                                                                                              286.6720
# #10- 4 1/8" x 9 1/2" Security-Tint Envelopes                                                                                         146.6880
# ...

# %% [markdown]
# ### 18.Find state wise sum of sales.

# %%
state_wise_df = df.groupby("State")["Sales"].sum()
state_wise_df
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %% [markdown]
# ### 19.Find month wise sum of sales

# %%
month_wise_sum = df.groupby([df["Order_Date"].dt.month])["Sales"].sum()
month_wise_sum
# Out:
# Order_Date
# 1      94924.8356
# 2      59751.2514
# 3     205005.4888
# 4     137762.1286
# 5     155028.8117
# 6     152718.6793
# 7     147238.0970
# 8     159044.0630
# 9     307649.9457
# 10    200322.9847
# 11    352461.0710
# 12    325293.5035
# Name: Sales, dtype: float64

# %% [markdown]
# ### 20.Find country wise and city wise average profit

# %%
county_city_avg = df.groupby(["Country","City"])["Profit"].mean()
county_city_avg
# Out:
# Country        City
# United States  Aberdeen               6.630000
#                Abilene               -3.758400
#                Akron                 -8.887410
#                Albuquerque           45.292007
#                Alexandria            19.913644
#                Allen                 -9.969375
#                Allentown            -32.350057
#                Altoona               -0.591750
#                Amarillo             -38.796830
#                Anaheim               45.703837
#                Andover               31.047150
#                Ann Arbor             45.783160
#                Antioch                9.331200
#                Apopka                 7.766200
#                Apple Valley          32.509889
#                Appleton             277.383150
#                Arlington             69.494948
#                Arlington Heights      1.234800
#                Arvada                14.963900
# ...

# %% [markdown]
# ### 21.Calculate region wise average profit

# %%
region_profit_avg = df.groupby("Region")["Profit"].mean()
region_profit_avg
# Out:
# Region
# Central    17.092709
# East       32.135808
# South      28.857673
# West       33.849032
# Name: Profit, dtype: float64

# %% [markdown]
# ### 22.Find the ship mode which is more profitable

# %%
ship_mode_max = df.groupby("Ship_Mode")["Profit"].max()
print(ship_mode_max)
print(ship_mode_max.max())
# Out:
# Ship_Mode
# First Class       6719.9808
# Same Day          2229.0240
# Second Class      2799.9840
# Standard Class    8399.9760
# Name: Profit, dtype: float64
# 8399.975999999999

# %% [markdown]
# ### 23.Create a new data frame where loss is recorded

# %%
loss_df = df["Sales"] - df["Profit"]
print(loss_df)
# Out:
# 1900       220.0464
# 1901       512.3580
# 1902         7.7486
# 1903      1340.6085
# 1904        19.8516
# 1905        34.6906
# 1906         5.3144
# 1907       816.4368
# 1908        12.7215
# 1909        80.4300
# 1910      1620.8748
# 1911       843.0672
# 1912        10.1088
# 1913       275.3838
# 1914       192.6680
# 1915         6.3600
# 1916       652.5624
# 1917        45.5100
# 1918         6.0776
# 1919       197.4690
# 1920        15.3360
# 1921        14.4004
# 1922        44.6516
# 1923        72.3916
# 1924       804.3651
# 1925         7.4256
# 1926        78.7959
# 1927      4748.4822
# 1928        16.6712
# 1929       108.6750
# 1930         2.1624
# 1931        76.5948
# 1932        12.5730
# 1933        12.2140
# 1934        19.5252
# 1935       974.0703
# 1936       338.8830
# 1937        77.9130
# 1938       579.3756
# 1939       227.2050
# 1940       329.4116
# 1941       130.6116
# 1942        73.9860
# 1943        86.0544
# 1944        26.2086
# ...

# %% [markdown]
# ### 24.Find category wise sub category wise sales

# %%
df.groupby(["Category","Sub-Category"])["Sales"].sum()
# Out:
# Category         Sub-Category
# Furniture        Bookcases       114879.9963
#                  Chairs          328449.1030
#                  Furnishings      91705.1640
#                  Tables          206965.5320
# Office Supplies  Appliances      107532.1610
#                  Art              27118.7920
#                  Binders         203412.7330
#                  Envelopes        16476.4020
#                  Fasteners         3024.2800
#                  Labels           12486.3120
#                  Paper            78479.2060
#                  Storage         223843.6080
#                  Supplies         46673.5380
# Technology       Accessories     167380.3180
#                  Copiers         149528.0300
#                  Machines        189238.6310
#                  Phones          330007.0540
# Name: Sales, dtype: float64

# %% [markdown]
# ### 25.Create a data frame for record where discount is 0

# %%
df[df["Discount"] == 0.0].head()
# Out:
#        no       order__id Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 1900  NaN             NaN 2016-11-08 2016-11-11    Second Class    CG-12520
# 1901  2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1902  3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 1905  6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 1906  7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#         Customer_Name    Segment        Country         City       State  \
# 1900      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1901      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1902  Darrin Van Huff  Corporate  United States  Los Angeles  California
# 1905  Brosina Hoffman   Consumer  United States  Los Angeles  California
# 1906  Brosina Hoffman   Consumer  United States  Los Angeles  California
#
# ...

# %%
df[df["Discount"] == 0.0].shape
# Out:
# (4798, 21)
